# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
sns.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

# %%
df = pd.read_csv('house_data_fix.csv')

# %%
df.head()
# Out:
#                        House Name  Price Room Type    Area Price per m2  \
# 0          世纪城垂虹园，购房成本低，小三居，金源，地铁   1499    2室2厅1卫  122.00       122869
# 1           光大花园 2室2厅1卫 格局方正 品质小区   1410    2室2厅1卫   94.93       148530
# 2  21年新装，拎包住！世纪城时雨园不临街高楼层+位置好+采光好   1660    3室2厅2卫  130.00       127692
# 3               万城华府大平层，精装修，，发假拉黑  20000   10室3厅8卫  744.28       268716
# 4         万柳书院 科技住宅 全明格局 有房本 随时交易   5400    3室2厅3卫  245.00       220408
#
#   Sun Direction Floor Level Furnishing  Review Year Built Lift  \
# 0            东南          低层        简装修     8.0       2017    有
# 1            东南          高层        精装修     6.6       2000    无
# 2            西南          高层        简装修     6.5       2004    有
# 3            南北          顶层        精装修     8.3       2000    有
# 4            南北          底层       豪华装修     8.0       2015    有
#
#   Property Quality Residence Type Building Structure Building Type  \
# 0              商品房           普通住宅                 平层    2023-06-15
# 1              商品房           普通住宅                 平层            板楼
# 2              商品房           普通住宅                 平层            板楼
# 3             个人产权           普通住宅                 板楼    2023-07-01
# 4             个人产权           普通住宅                 平层            砖楼
#
#    Leasing Date
# 0  118732\n元/平米
# 1    2023-07-02
# 2    2023-06-14
# 3  176236\n元/平米
# 4    2023-06-25

# %%
lift_clean = df[(df['Lift']== '有')|(df['Lift']=='无')]

# %%
sns.countplot(x='Lift', data = lift_clean, palette = 'coolwarm')
# Out:
# <AxesSubplot: xlabel='Lift', ylabel='count'>

# %%
df['Floor Level'].value_counts()
# Out:
# 中层    1594
# 低层    1166
# 高层    1072
# 底层     995
# 顶层     888
# 地下      12
# Name: Floor Level, dtype: int64

# %%
sns.countplot(x="Floor Level", hue="Lift",data=lift_clean, palette="Set2")
# Out:
# <AxesSubplot: xlabel='Floor Level', ylabel='count'>

# %%
df['Price per m2'].value_counts()
# Out:
# 100000    27
# 暂无价格      17
# 137500    15
# 125000    14
# 153392    14
#           ..
# 101653     1
# 67860      1
# 106119     1
# 104977     1
# 80651      1
# Name: Price per m2, Length: 2445, dtype: int64

# %%
price_clean = df[df['Price per m2'] != '暂无价格']

# %%
price_clean.head()
# Out:
#                        House Name  Price Room Type    Area Price per m2  \
# 0          世纪城垂虹园，购房成本低，小三居，金源，地铁   1499    2室2厅1卫  122.00       122869
# 1           光大花园 2室2厅1卫 格局方正 品质小区   1410    2室2厅1卫   94.93       148530
# 2  21年新装，拎包住！世纪城时雨园不临街高楼层+位置好+采光好   1660    3室2厅2卫  130.00       127692
# 3               万城华府大平层，精装修，，发假拉黑  20000   10室3厅8卫  744.28       268716
# 4         万柳书院 科技住宅 全明格局 有房本 随时交易   5400    3室2厅3卫  245.00       220408
#
#   Sun Direction Floor Level Furnishing  Review Year Built Lift  \
# 0            东南          低层        简装修     8.0       2017    有
# 1            东南          高层        精装修     6.6       2000    无
# 2            西南          高层        简装修     6.5       2004    有
# 3            南北          顶层        精装修     8.3       2000    有
# 4            南北          底层       豪华装修     8.0       2015    有
#
#   Property Quality Residence Type Building Structure Building Type  \
# 0              商品房           普通住宅                 平层    2023-06-15
# 1              商品房           普通住宅                 平层            板楼
# 2              商品房           普通住宅                 平层            板楼
# 3             个人产权           普通住宅                 板楼    2023-07-01
# 4             个人产权           普通住宅                 平层            砖楼
#
#    Leasing Date
# 0  118732\n元/平米
# 1    2023-07-02
# 2    2023-06-14
# 3  176236\n元/平米
# 4    2023-06-25

# %%
price_clean['Price per m2'] = price_clean['Price per m2'].astype(float)
# Out:
# C:\Users\Theodore\AppData\Local\Temp\ipykernel_13696\1896636986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_clean['Price per m2'] = price_clean['Price per m2'].astype(float)

# %%
sns.boxplot(x="Furnishing", y="Price per m2", data=price_clean,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='Furnishing', ylabel='Price per m2'>

# %%
sns.boxplot(x="Sun Direction", y="Price per m2", data=price_clean,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='Sun Direction', ylabel='Price per m2'>

# %%
df['Sun Direction'].value_counts()
# Out:
# 南北    3207
# 南      670
# 西南     485
# 东南     378
# 东西     328
# 东      181
# 西北     166
# 西      152
# 东北     108
# 北       52
# Name: Sun Direction, dtype: int64

# %%
sns.boxplot(x="Floor Level", y="Price per m2",data=price_clean,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='Floor Level', ylabel='Price per m2'>

# %%
raw_price_clean = df[df['Price'] != '暂无报价']
raw_price_clean['Area']=raw_price_clean['Area'].astype(float)
raw_price_clean['Price']=raw_price_clean['Price'].astype(float)
# Out:
# C:\Users\Theodore\AppData\Local\Temp\ipykernel_13696\3171429812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_price_clean['Area']=raw_price_clean['Area'].astype(float)
# C:\Users\Theodore\AppData\Local\Temp\ipykernel_13696\3171429812.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_price_clean['Price']=raw_price_clean['Price'].astype(float)

# %%
raw_price_clean.head()
# Out:
#                        House Name    Price Room Type    Area Price per m2  \
# 0          世纪城垂虹园，购房成本低，小三居，金源，地铁   1499.0    2室2厅1卫  122.00       122869
# 1           光大花园 2室2厅1卫 格局方正 品质小区   1410.0    2室2厅1卫   94.93       148530
# 2  21年新装，拎包住！世纪城时雨园不临街高楼层+位置好+采光好   1660.0    3室2厅2卫  130.00       127692
# 3               万城华府大平层，精装修，，发假拉黑  20000.0   10室3厅8卫  744.28       268716
# 4         万柳书院 科技住宅 全明格局 有房本 随时交易   5400.0    3室2厅3卫  245.00       220408
#
#   Sun Direction Floor Level Furnishing  Review Year Built Lift  \
# 0            东南          低层        简装修     8.0       2017    有
# 1            东南          高层        精装修     6.6       2000    无
# 2            西南          高层        简装修     6.5       2004    有
# 3            南北          顶层        精装修     8.3       2000    有
# 4            南北          底层       豪华装修     8.0       2015    有
#
#   Property Quality Residence Type Building Structure Building Type  \
# 0              商品房           普通住宅                 平层    2023-06-15
# 1              商品房           普通住宅                 平层            板楼
# 2              商品房           普通住宅                 平层            板楼
# 3             个人产权           普通住宅                 板楼    2023-07-01
# 4             个人产权           普通住宅                 平层            砖楼
#
#    Leasing Date
# 0  118732\n元/平米
# 1    2023-07-02
# 2    2023-06-14
# 3  176236\n元/平米
# 4    2023-06-25

# %%
plot1= sns.jointplot(x='Price',y='Area',data=raw_price_clean,kind='reg', joint_kws={'color':'Orange'})
plot1.ax_marg_y.set_ylim(0, 1000)
plot1.ax_marg_x.set_xlim(0, 15000)
# Out:
# (0.0, 15000.0)

# %%
raw_price_clean['Price'].max()
# Out:
# 45000.0

# %%
raw_price_clean['Price'].mean()
# Out:
# 1905.9462031523644
